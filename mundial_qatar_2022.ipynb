# %% [markdown]
# ## Librerias

# %%
# %pip install pandas
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Python310\python.exe -m pip install --upgrade pip' command.
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lectura de datos
#
# - [Dataset Qatar 2022: https://www.kaggle.com/datasets/die9origephit/fifa-world-cup-2022-complete-dataset](https://www.kaggle.com/datasets/die9origephit/fifa-world-cup-2022-complete-dataset)

# %%
archivo = "https://raw.githubusercontent.com/IgnacioPardo/Tecnologias_Exponenciales_2024/main/Qatar_2022/Fifa_world_cup_matches.csv"

# Leer datos del archivo
mundial : pd.DataFrame = pd.read_csv(archivo)
mundial
# Out:
#             team1         team2 possession team1 possession team2  \
# 0           QATAR       ECUADOR              42%              50%
# 1         ENGLAND          IRAN              72%              19%
# 2         SENEGAL   NETHERLANDS              44%              45%
# 3   UNITED STATES         WALES              51%              39%
# 4       ARGENTINA  SAUDI ARABIA              64%              24%
# ..            ...           ...              ...              ...
# 59        ENGLAND        FRANCE              54%              36%
# 60      ARGENTINA       CROATIA              34%              54%
# 61         FRANCE       MOROCCO              34%              55%
# 62        CROATIA       MOROCCO              45%              45%
# 63      ARGENTINA        FRANCE              46%              40%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 0                     8%                      0                      2
# ...

# %%
# Checkear tipo de mundial
# Completar

type(mundial)
# Out:
# pandas.core.frame.DataFrame

# %%
# Que datos tiene el dataset? (Pista: usar .info(), .describe(), .columns, .head())
# Checkear columnas
# Completar

mundial.info()
mundial.describe()
mundial.columns
mundial.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 88 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   team1                                                  64 non-null     object
#  1   team2                                                  64 non-null     object
#  2   possession team1                                       64 non-null     object
#  3   possession team2                                       64 non-null     object
#  4   possession in contest                                  64 non-null     object
#  5   number of goals team1                                  64 non-null     int64
#  6   number of goals team2                                  64 non-null     int64
#  7   date                                                   64 non-null     object
# ...

# %% [markdown]
# ## Analisis

# %% [markdown]
# ### Primera Parte

# %%
equipo : str = "ARGENTINA"

# %%
# Seleccionar todos los partidos que jugo el equipo de "local"
# Completar

filtroLocal : pd.Series = mundial["team1"] == equipo

# %%
# Seleccionar todos los partidos que jugo el equipo de "visitante"
# Completar

filtroVisitante : pd.Series = mundial["team2"] == equipo

# %%
# Seleccionar todos los partidos que jugo el equipo (de "local" o "visitante")
# Completar

partidos : pd.DataFrame = mundial[filtroLocal | filtroVisitante]
partidos
# Out:
#           team1         team2 possession team1 possession team2  \
# 4     ARGENTINA  SAUDI ARABIA              64%              24%
# 23    ARGENTINA        MEXICO              50%              36%
# 38       POLAND     ARGENTINA              24%              67%
# 49    ARGENTINA     AUSTRALIA              53%              35%
# 57  NETHERLANDS     ARGENTINA              45%              44%
# 60    ARGENTINA       CROATIA              34%              54%
# 63    ARGENTINA        FRANCE              46%              40%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 4                    12%                      1                      2
# 23                   14%                      2                      0
# 38                    9%                      0                      2
# 49                   12%                      2                      1
# 57                   11%                      2                      2
# ...

# %%
# Cuantos goles hizo el equipo en total (obtener los goles metidos de local y sumarlos con los goles metidos de visitante)
# Completar


partidos_local: pd.DataFrame = mundial[filtroLocal]
partidos_visitante: pd.DataFrame = mundial[filtroVisitante]


goles_local: int = partidos_local["number of goals team1"].sum()

goles_visitante: int = partidos_visitante["number of goals team2"].sum()

goles = goles_local + goles_visitante

goles
# Out:
# 15

# %%
# Cuantos goles hizo el equipo en promedio
# Completar

cantPartidosLocal = len(partidos_local)

cantPartidosVisitante = len(partidos_visitante)

cantPartidosTotal : int = cantPartidosLocal + cantPartidosVisitante

promedioGoles : int = goles / cantPartidosTotal

promedioGoles
# Out:
# 2.142857142857143

# %%
# Cuantos partidos gano el equipo
# Completar

#este fue mi primer codigo y me tiraba error, entonces le pedi a chatGpt que me lo corrija.
# ganados : int
# if partidos_local["number of goals team1"] > partidos_local["number of goals team2"] :
#     ganados += 1
# elif partidos_visitante["number of goals team1"] > partidos_visitante["number of goals team2"] :
#     ganados += 1
# ganados

ganados = 0

ganados_local : int= (partidos_local["number of goals team1"] > partidos_local["number of goals team2"]).sum()

ganados_visitante : int = (partidos_visitante["number of goals team1"] < partidos_visitante["number of goals team2"]).sum()

ganados : int = ganados_local + ganados_visitante

ganados
# Out:
# 4

# %%
# Le pedi a chat que me ayude a hacer el grafico

# Graficar los goles hechos por el equipo en cada partido
# Obtener solo los goles hechos por Argentina en cada partido
goles_argentina = partidos["number of goals team1"].where(filtroLocal, partidos["number of goals team2"])
partidos["goles_argentina"] = goles_argentina
partidos = partidos.dropna()

# Ordenar por fecha
partidos = partidos.sort_values(by="date")

# Filtrar las fechas donde se marcaron goles de Argentina
fechas_con_goles = partidos[partidos["goles_argentina"] > 0]["date"]

# Graficar los goles hechos por Argentina en cada fecha donde se marcaron goles
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(partidos["date"], partidos["goles_argentina"], marker='o', linestyle='-', color='lightgray')
ax.scatter(fechas_con_goles, partidos.loc[partidos["goles_argentina"] > 0, "goles_argentina"], color='#527a7a', label="Goles de Argentina")
ax.set_xlabel("Fecha")
ax.set_ylabel("Goles")
ax.set_title(f"Goles hechos por {equipo} en cada partido")
plt.xticks(fechas_con_goles, rotation=45)
plt.tight_layout()
plt.legend()
plt.show()

# Completar
# Out:
# C:\Users\48521682\AppData\Local\Temp\ipykernel_13412\1788918102.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   partidos["goles_argentina"] = goles_argentina

# %% [markdown]
# ### Segunda Parte

# %%
# Contar cuantos goles hizo cada equipo en total en el mundial
# Completar

# En este ejercicio me inspire en chatGPT para hacer el ultimo for y en la idea del diccionario
equipos = set(mundial["team1"]).union(mundial["team2"])

# Diccionario para almacenar los goles de cada equipo y calcular los goles totales
goles = {}

for equipo in equipos:

    filtroLocal = mundial["team1"] == equipo
    filtroVisitante = mundial["team2"] == equipo
    partidos_local = mundial[filtroLocal]
    partidos_visitante = mundial[filtroVisitante]
    
    # Suma de los goles del equipo como local y visitante
    goles_local = partidos_local["number of goals team1"].sum()
    goles_visitante = partidos_visitante["number of goals team2"].sum()
    
    # Goles totales del equipo
    goles_totales = goles_local + goles_visitante
    
    # Poner los goles en el diccionario
    goles[equipo] = goles_totales

# Printear total de goles de cada equipo
for equipo, total_goles in goles.items():
    print(f"{equipo}: {total_goles} goles")
# Out:
# COSTA RICA: 3 goles
# BELGIUM: 1 goles
# GHANA: 5 goles
# ENGLAND: 13 goles
# PORTUGAL: 12 goles
# NETHERLANDS: 10 goles
# URUGUAY: 2 goles
# CAMEROON: 4 goles
# GERMANY: 6 goles
# ARGENTINA: 15 goles
# DENMARK: 1 goles
# AUSTRALIA: 4 goles
# UNITED STATES: 3 goles
# IRAN: 4 goles
# QATAR: 1 goles
# CANADA: 2 goles
# WALES: 1 goles
# SAUDI ARABIA: 3 goles
# SENEGAL: 5 goles
# SWITZERLAND: 5 goles
# TUNISIA: 1 goles
# CROATIA: 8 goles
# SPAIN: 9 goles
# BRAZIL: 8 goles
# KOREA REPUBLIC: 5 goles
# MEXICO: 2 goles
# FRANCE: 16 goles
# SERBIA: 5 goles
# JAPAN: 5 goles
# MOROCCO: 6 goles
# POLAND: 3 goles
# ECUADOR: 4 goles

# %%
# Graficar los goles por equipo en todo el mundial

fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(goles.keys(), goles.values(), color="#527a7a")
ax.set_xlabel("Equipo")
ax.set_ylabel("Total de Goles")
ax.set_title("Goles por Equipo en el Mundial")
plt.xticks(rotation=45, ha='right')  # Rotar las etiquetas del eje x para mayor legibilidad
ax.set_ylim(0, 20)  # Establecer el rango del eje y
plt.tight_layout()
plt.show()

# Completar

# %%
# Cual es el equipo que hizo mas goles en el mundial?
# Completar

# Me inspire en chatGPT

equipoMasGoles = max(goles, key=goles.get)
cantGoles = goles[equipoMasGoles]

print(f"El equipo que hizo más goles en el mundial fue {equipoMasGoles} con un total de {cantGoles} goles.")
# Out:
# El equipo que hizo más goles en el mundial fue FRANCE con un total de 16 goles.

# %%
# Por cada partido, cual fue la diferencia de goles?
# Completar

mundial["diferencia_de_goles"] = mundial["number of goals team1"] - mundial["number of goals team2"]

print(mundial[["team1", "team2", "diferencia_de_goles"]])
# Out:
#             team1         team2  diferencia_de_goles
# 0           QATAR       ECUADOR                   -2
# 1         ENGLAND          IRAN                    4
# 2         SENEGAL   NETHERLANDS                   -2
# 3   UNITED STATES         WALES                    0
# 4       ARGENTINA  SAUDI ARABIA                   -1
# ..            ...           ...                  ...
# 59        ENGLAND        FRANCE                   -1
# 60      ARGENTINA       CROATIA                    3
# 61         FRANCE       MOROCCO                    2
# 62        CROATIA       MOROCCO                    1
# 63      ARGENTINA        FRANCE                    0
#
# [64 rows x 3 columns]

# %%
# Por cada partido, cual fue el equipo que gano?
# Completar

# Hice este codigo por mi cuenta y me tiraba error, por lo tanto lo corregi con ayuda de chatGPT

# mundial["winner"]
# if mundial["number of goals team1"] > mundial["number of goals team2"] : 
#     mundial["winner"] = "team1"
# elif mundial["number of goals team1"] < mundial["number of goals team2"] : 
#     mundial["winner"] = "team2"
# elif mundial["number of goals team1"] == mundial["number of goals team2"] :
#     mundial["winner"] = "---"
# print(mundial[["team1", "team2", "winner"]])

# Crear la columna "winner" en el DataFrame mundial
mundial["winner"] = "---"  # Inicializar todas las filas con un valor predeterminado

# Asignar el equipo ganador basado en la diferencia de goles
for i, row in mundial.iterrows():
    if row["number of goals team1"] > row["number of goals team2"]:
        mundial.at[i, "winner"] = row["team1"]
    elif row["number of goals team1"] < row["number of goals team2"]:
        mundial.at[i, "winner"] = row["team2"]

# Mostrar el resultado
print(mundial[["team1", "team2", "winner"]])
# Out:
#             team1         team2        winner
# 0           QATAR       ECUADOR       ECUADOR
# 1         ENGLAND          IRAN       ENGLAND
# 2         SENEGAL   NETHERLANDS   NETHERLANDS
# 3   UNITED STATES         WALES           ---
# 4       ARGENTINA  SAUDI ARABIA  SAUDI ARABIA
# ..            ...           ...           ...
# 59        ENGLAND        FRANCE        FRANCE
# 60      ARGENTINA       CROATIA     ARGENTINA
# 61         FRANCE       MOROCCO        FRANCE
# 62        CROATIA       MOROCCO       CROATIA
# 63      ARGENTINA        FRANCE           ---
#
# [64 rows x 3 columns]

# %%
# En cada fase del mundial, cual fue el equipo que hizo mas goles?
# Completar

#Ayudas que me diste
#sort
#groupby

#Intento fallido de hacerlo
# golesPorCategoria : pd.DataFrame= mundial.groupby("category")[["number of goals team1", "number of goals team2"]].count()
# golesPorCategoria

#Respuesta de chatGPT
# Agrupar los partidos por fase y equipo, y sumar los goles
goles_por_fase_equipo = mundial.groupby(["category"]).apply(lambda x: x.groupby(["team1"])["number of goals team1"].sum().add(
    x.groupby(["team2"])["number of goals team2"].sum(), fill_value=0)).reset_index()

# Renombrar las columnas
goles_por_fase_equipo.columns = ["category", "team", "total_goals"]

# Encontrar el equipo con más goles en cada fase
max_goles_por_fase = goles_por_fase_equipo.loc[goles_por_fase_equipo.groupby("category")["total_goals"].idxmax()]

print(max_goles_por_fase)
# Out:
#                     category         team  total_goals
# 0                      Final    ARGENTINA          3.0
# 3                    Group A  NETHERLANDS          5.0
# 6                    Group B      ENGLAND          9.0
# 10                   Group C    ARGENTINA          5.0
# 16                   Group D       FRANCE          6.0
# 21                   Group E        SPAIN          9.0
# 24                   Group F      CROATIA          4.0
# 28                   Group G       SERBIA          5.0
# 32                   Group H     PORTUGAL          6.0
# 34  Play-off for third place      CROATIA          2.0
# 36             Quarter-final    ARGENTINA          2.0
# 55               Round of 16     PORTUGAL          6.0
# 60                Semi-final    ARGENTINA          3.0
# ...

# %% [markdown]
# ### Tercera Parte

# %%
# Armar un gráfico a partir de algun nuevo análisis que se te ocurra
# Completar

# Hacer un grafico que muestre las fases y la cantidad total de goles convertidos en cada una

# Calcula la cantidad de goles en cada fase

    # Primero hice este codigo para calcular la cantidad de goles por fase, pero me daba erroneo. Lo cambie con ayuda de chatGPT
    # mundial["goals per category"] = 0
    # golesPorFase = set(mundial.groupby("category")[["number of goals team1", "number of goals team2"]].sum().sum(axis=1))
    # mundial["goals per category"] = golesPorFase
    # print(mundial[["category", "goals per category"]])

mundial["goals per category"] = 0
goles_por_categoria = mundial.groupby("category")[["number of goals team1", "number of goals team2"]].sum().sum(axis=1)
mundial["goals per category"] = mundial["category"].map(goles_por_categoria)
print(mundial[["category", "goals per category"]])

# crea el grafico para indicar la cantidad de goles hechos por fase (category)
fig, ax = plt.subplots(figsize=(10, 6))
goles_por_categoria.plot(kind='bar', ax=ax, color='#d966ff')
ax.set_xlabel("Fase")
ax.set_ylabel("Total de Goles")
ax.set_title("Total de Goles por Fase en el Mundial")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
#                     category  goals per category
# 0                    Group A                  15
# 1                    Group B                  16
# 2                    Group A                  15
# 3                    Group B                  16
# 4                    Group C                  12
# ..                       ...                 ...
# 59             Quarter-final                  10
# 60                Semi-final                   5
# 61                Semi-final                   5
# 62  Play-off for third place                   3
# 63                     Final                   6
#
# [64 rows x 2 columns]

# %%
mundial
# Out:
#             team1         team2 possession team1 possession team2  \
# 0           QATAR       ECUADOR              42%              50%
# 1         ENGLAND          IRAN              72%              19%
# 2         SENEGAL   NETHERLANDS              44%              45%
# 3   UNITED STATES         WALES              51%              39%
# 4       ARGENTINA  SAUDI ARABIA              64%              24%
# ..            ...           ...              ...              ...
# 59        ENGLAND        FRANCE              54%              36%
# 60      ARGENTINA       CROATIA              34%              54%
# 61         FRANCE       MOROCCO              34%              55%
# 62        CROATIA       MOROCCO              45%              45%
# 63      ARGENTINA        FRANCE              46%              40%
#
#    possession in contest  number of goals team1  number of goals team2  \
# 0                     8%                      0                      2
# ...
